# %%
%connect 'COM5' --baudrate=115200 --user='micro' --password='python' --wait=0
# Out:
# Connected on COM5

# %%
import hub

hub.sound.beep()

# %%
# Come Command
import hub 
import utime

m1 = hub.port.F.motor
m2 = hub.port.E.motor
m3 = hub.port.D.motor
m4 = hub.port.C.motor

ultrasonic = hub.port.B.device
# button = hub.port.A.device
dist = 1000000

m1.pwm(-50)
m2.pwm(50)

while True:
    try:
        dist = ultrasonic.get()[0]
        if dist <= 30:
            m1.pwm(0)
            m2.pwm(0)
            break
    except:
        pass
print("Dog Ready")
# Out:
# here

# %% [markdown]
# m1.pwm(0)

# %%
m1.pwm(0)
m2.pwm(0)

# %%
import hub 
import utime

ForceSensor = hub.port.A.device

start_time = utime.ticks_ms()
curr_time = start_time
force = 0 

while ((curr_time - start_time) < 10000) and force < 500:
#     print(curr_time - start_time)
    ForceSensor.mode(4)        # Force in RAW units
    force = ForceSensor.get()[0]
    curr_time = utime.ticks_ms()
    print(force)
    
hub.sound.beep()
# Out:
# 378
# 377
# 378
# 377
# 377
# 378
# 377
# 377
# 377
# 378
# 378
# 377
# 377
# 377
# 378
# 378
# 377
# 377
# 377
# 377
# 377
# 378
# 378
# 378
# 377
# 377
# 378
# 378
# 377
# 378
# 378
# 378
# 378
# 377
# 378
# 378
# 377
# 378
# 377
# 377
# 377
# 378
# 377
# 377
# 378
# 378
# 378
# 377
# 377
# 378
# 377
# 378
# 377
# 377
# 377
# 377
# 377
# 377
# 378
# 378
# 378
# 378
# 377
# 378
# 378
# 378
# 377
# 377
# 377
# 377
# 378
# 377
# 377
# 378
# 377
# 378
# 378
# 378
# 377
# 377
# 377
# 377
# 378
# 377
# 378
# 377
# 377
# 377
# 378
# 378
# 378
# 378
# 377
# 378
# 378
# 378
# 378
# 378
# 377
# 378
# 377
# 377
# 378
# 377
# 378
# 378
# 378
# 378
# 377
# 378
# 377
# 377
# 377
# 377
# 377
# 378
# 378
# 377
# 378
# 377
# 377
# 378
# 377
# 377
# 378
# 378
# 377
# 377
# 377
# 377
# 378
# 377
# 377
# 377
# 378
# 378
# 377
# 377
# 377
# 378
# 377
# 378
# 378
# 378
# 378
# 377
# 378
# 377
# 377
# 378
# 378
# 377
# 377
# 377
# 377
# 378
# 377
# 378
# 378
# 377
# 378
# 377
# 377
# 378
# 378
# 377
# ...
